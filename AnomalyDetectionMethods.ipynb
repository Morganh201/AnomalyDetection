# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
import keras
import keras.optimizers as optimizers
from keras import layers, callbacks
from keras import regularizers
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import mean_squared_error as mse
import pyreadr
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Data Preprocessing

# %%
df_normal_train = pyreadr.read_r("TEP_FaultFree_Training.RData")
df_normal_train = df_normal_train['fault_free_training']
df_normal_test = pyreadr.read_r("TEP_FaultFree_Testing.RData")
df_normal_test = df_normal_test['fault_free_testing']
df_normal_test.head()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            0            1.0       1  0.25171   3672.4   4466.3   9.5122
# 1            0            1.0       2  0.25234   3642.2   4568.7   9.4145
# 2            0            1.0       3  0.24840   3643.1   4507.5   9.2901
# 3            0            1.0       4  0.25153   3628.3   4519.3   9.3347
# 4            0            1.0       5  0.21763   3655.8   4571.0   9.3087
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   27.057   42.473   2705.6  ...  54.494  24.527  59.710  22.357  40.149
# 1   26.999   42.586   2705.2  ...  53.269  24.465  60.466  22.413  39.956
# 2   26.927   42.278   2703.5  ...  54.000  24.860  60.642  22.199  40.074
# 3   26.999   42.330   2703.9  ...  53.860  24.553  61.908  21.981  40.141
# 4   26.901   42.402   2707.7  ...  53.307  21.775  61.891  22.412  37.696
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 0  40.074  47.955  47.300  42.100  15.345
# 1  36.651  45.038  47.502  40.553  16.063
# 2  41.868  44.553  47.479  41.341  20.452
# 3  40.066  48.048  47.440  40.780  17.123
# 4  38.295  44.678  47.530  41.089  18.681
#
# [5 rows x 55 columns]

# %%
df_faulty_train = pyreadr.read_r("TEP_Faulty_Training.RData")
df_faulty_train = df_faulty_train['faulty_training']
df_faulty_test = pyreadr.read_r("TEP_Faulty_Testing.RData")
df_faulty_test = df_faulty_test['faulty_testing']
df_faulty_train
# Out:
#          faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  \
# 0                  1            1.0       1  0.25038   3674.0   4529.0
# 1                  1            1.0       2  0.25109   3659.4   4556.6
# 2                  1            1.0       3  0.25038   3660.3   4477.8
# 3                  1            1.0       4  0.24977   3661.3   4512.1
# 4                  1            1.0       5  0.29405   3679.0   4497.0
# ...              ...            ...     ...      ...      ...      ...
# 4999995           20          500.0     496  0.23419   3655.3   4461.7
# 4999996           20          500.0     497  0.26704   3647.4   4540.2
# 4999997           20          500.0     498  0.26543   3630.3   4571.6
# 4999998           20          500.0     499  0.27671   3655.7   4498.9
# 4999999           20          500.0     500  0.27421   3640.4   4474.4
#
#          xmeas_4  xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4  \
# 0         9.2320   26.889   42.402   2704.3  ...  53.744  24.657  62.544
# 1         9.4264   26.721   42.576   2705.0  ...  53.414  24.588  59.259
# 2         9.4426   26.875   42.070   2706.2  ...  54.357  24.666  61.275
# 3         9.4776   26.758   42.063   2707.2  ...  53.946  24.725  59.856
# 4         9.3381   26.889   42.650   2705.1  ...  53.658  28.797  60.717
# ...          ...      ...      ...      ...  ...     ...     ...     ...
# 4999995   9.3448   27.008   42.481   2703.0  ...  53.670  23.350  61.061
# 4999996   9.3546   27.034   42.671   2704.7  ...  54.650  26.362  60.020
# 4999997   9.4089   27.129   42.470   2705.1  ...  54.274  26.521  59.824
# 4999998   9.3781   27.353   42.281   2705.8  ...  53.506  26.781  62.818
# 4999999   9.3866   27.145   41.985   2706.0  ...  53.800  27.027  59.757
#
#           xmv_5   xmv_6   xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# 0        22.137  39.935  42.323  47.757  47.510  41.258  18.447
# 1        22.084  40.176  38.554  43.692  47.427  41.359  17.194
# 2        22.380  40.244  38.990  46.699  47.468  41.199  20.530
# 3        22.277  40.257  38.072  47.541  47.658  41.643  18.089
# 4        21.947  39.144  41.955  47.645  47.346  41.507  18.461
# ...         ...     ...     ...     ...     ...     ...     ...
# 4999995  20.719  40.999  38.653  47.386  47.528  40.212  17.659
# 4999996  20.263  41.579  33.624  47.536  47.647  41.199  18.741
# 4999997  20.189  41.505  40.967  52.437  47.802  41.302  23.199
# 4999998  20.453  40.208  40.957  47.628  48.086  40.510  15.932
# 4999999  20.157  40.326  36.039  48.885  48.170  41.115  15.752
#
# [5000000 rows x 55 columns]

# %%
df_normal_train.columns
# Out:
# Index(['faultNumber', 'simulationRun', 'sample', 'xmeas_1', 'xmeas_2',
#        'xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
#        'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
#        'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
#        'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
#        'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
#        'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
#        'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
#        'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 6))
process = 38
index = 7
plt.subplot(221)
plt.plot(df_normal_train[f'xmeas_{process}'][index*500:index*500+500])
plt.subplot(222)
plt.plot(df_normal_test[f'xmeas_{process}'][index*960:index*960+960])
plt.subplot(223)
plt.plot(df_faulty_train[f'xmeas_{process}'][index*500:index*500+500])
plt.subplot(224)
plt.plot(df_faulty_test[f'xmeas_{process}'][index*960:index*960+960])
plt.show()

# %%
features = ['xmeas_1', 'xmeas_2','xmeas_3', 'xmeas_4', 'xmeas_5', 'xmeas_6', 'xmeas_7', 'xmeas_8',
       'xmeas_9', 'xmeas_10', 'xmeas_11', 'xmeas_12', 'xmeas_13', 'xmeas_14',
       'xmeas_15', 'xmeas_16', 'xmeas_17', 'xmeas_18', 'xmeas_19', 'xmeas_20',
       'xmeas_21', 'xmeas_22', 'xmeas_23', 'xmeas_24', 'xmeas_25', 'xmeas_26',
       'xmeas_27', 'xmeas_28', 'xmeas_29', 'xmeas_30', 'xmeas_31', 'xmeas_32',
       'xmeas_33', 'xmeas_34', 'xmeas_35', 'xmeas_36', 'xmeas_37', 'xmeas_38',
       'xmeas_39', 'xmeas_40', 'xmeas_41', 'xmv_1', 'xmv_2', 'xmv_3', 'xmv_4',
       'xmv_5', 'xmv_6', 'xmv_7', 'xmv_8', 'xmv_9', 'xmv_10', 'xmv_11']
datasets = [df_normal_train, df_normal_test, df_faulty_train, df_faulty_test]

# %%
scaler = MinMaxScaler()
for df in datasets:
    a = scaler.fit_transform(df[features])
    df[features] = a
    df
df_normal_test
# Out:
#         faultNumber  simulationRun  sample   xmeas_1   xmeas_2   xmeas_3  \
# 0                 0            1.0       1  0.482238  0.526136  0.364957
# 1                 0            1.0       2  0.484592  0.432172  0.656695
# 2                 0            1.0       3  0.469874  0.434972  0.482336
# 3                 0            1.0       4  0.481566  0.388923  0.515954
# 4                 0            1.0       5  0.354936  0.474487  0.663248
# ...             ...            ...     ...       ...       ...       ...
# 479995            0          500.0     956  0.529192  0.523335  0.491738
# 479996            0          500.0     957  0.480781  0.218108  0.415100
# 479997            0          500.0     958  0.479773  0.371189  0.270940
# 479998            0          500.0     959  0.457958  0.489110  0.418803
# 479999            0          500.0     960  0.452430  0.462974  0.380627
#
#          xmeas_4   xmeas_5   xmeas_6   xmeas_7  ...     xmv_2     xmv_3  \
# 0       0.708713  0.575942  0.570481  0.547033  ...  0.624504  0.473927
# 1       0.588481  0.543792  0.632946  0.541245  ...  0.338623  0.471584
# 2       0.435393  0.503880  0.462687  0.516643  ...  0.509218  0.486510
# 3       0.490278  0.543792  0.491432  0.522431  ...  0.476546  0.474909
# 4       0.458282  0.489468  0.531233  0.577424  ...  0.347491  0.369937
# ...          ...       ...       ...       ...  ...       ...       ...
# 479995  0.429363  0.622506  0.473190  0.464544  ...  0.495683  0.530419
# 479996  0.431824  0.324834  0.480929  0.438495  ...  0.453209  0.476119
# 479997  0.570391  0.381929  0.273632  0.458755  ...  0.594632  0.477177
# 479998  0.556485  0.508869  0.662244  0.473227  ...  0.343291  0.468032
# 479999  0.614817  0.715632  0.317302  0.522431  ...  0.380863  0.473511
#
#            xmv_4     xmv_5     xmv_6     xmv_7     xmv_8     xmv_9    xmv_10  \
# 0       0.367872  0.522155  0.533329  0.594539  0.579963  0.476661  0.702419
# 1       0.438315  0.533805  0.519701  0.463072  0.434135  0.484882  0.395718
# 2       0.454715  0.489286  0.528033  0.663440  0.409889  0.483946  0.551943
# 3       0.572680  0.443936  0.532764  0.594231  0.584612  0.482359  0.440722
# 4       0.571096  0.533597  0.360119  0.526213  0.416138  0.486021  0.501983
# ...          ...       ...       ...       ...       ...       ...       ...
# 479995  0.554137  0.534637  0.558819  0.466144  0.687947  0.697269  0.469865
# 479996  0.512952  0.432910  0.515252  0.366478  0.567915  0.704879  0.566019
# 479997  0.557492  0.491991  0.529727  0.422130  0.594261  0.712652  0.315821
# 479998  0.656821  0.499688  0.490044  0.423052  0.506974  0.715012  0.497224
# 479999  0.463287  0.599958  0.461446  0.556285  0.356097  0.725186  0.602498
#
#           xmv_11
# 0       0.328431
# 1       0.380963
# 2       0.702078
# 3       0.458516
# 4       0.572505
# ...          ...
# 479995  0.585162
# 479996  0.584650
# 479997  0.434226
# 479998  0.456614
# 479999  0.427349
#
# [480000 rows x 55 columns]

# %%
# Create sequences

n_training = df_normal_train.drop(['faultNumber', 'simulationRun', 'sample'], axis=1)
n_testing = df_normal_test.drop(['faultNumber', 'simulationRun', 'sample'], axis=1)
f_training = df_faulty_train.drop(['faultNumber', 'simulationRun', 'sample'], axis=1)
f_testing = df_faulty_test.drop(['faultNumber', 'simulationRun', 'sample'], axis=1)
def create_sequences(data, sample_length):
    X = []
    for i in range(0, len(data), sample_length):
        X.append(data[i:i+sample_length])
    X = np.array(X)
    return X

n_train = create_sequences(n_training, 500)
n_test = create_sequences(n_testing, 960)
f_train = create_sequences(f_training, 500)
f_test = create_sequences(f_testing, 960)
n_train.shape
# Out:
# (500, 500, 52)

# %%
f_train.shape
# Out:
# (10000, 500, 52)

# %% [markdown]
# ## Conventional Methods

# %%
# PCA

from sklearn.decomposition import PCA
pca = PCA(n_components=25)
pca.fit(n_training)
# Out:
# PCA(n_components=25)

# %%
# Reconstruct the normal data

X_pca = pca.transform(n_testing)
X_rec = pca.inverse_transform(X_pca)
X_rec = create_sequences(X_rec, 500)
X_rec.shape
# Out:
# (500, 500, 52)

# %%
# Get threshold for anomaly score

error = np.mean(np.abs(n_train - X_rec), axis=1)
threshold = np.max(np.max(error, axis=0))
threshold
# Out:
# 0.08581170599974403

# %%
# Predict using faulty data

y_pca = pca.transform(n_training)
y_rec = pca.inverse_transform(y_pca)
y_rec = create_sequences(y_rec, 500)
y_rec.shape
# Out:
# (500, 500, 52)

# %%
# Calculate reconstruction error

f_error = np.mean(np.abs(n_train - y_rec), axis=1)
f_error
# Out:
# array([[0.01496443, 0.05729057, 0.06342672, ..., 0.01327767, 0.05415914,
#         0.00269632],
#        [0.01461247, 0.05814431, 0.06591729, ..., 0.01603205, 0.04942978,
#         0.00302257],
#        [0.01581368, 0.05683092, 0.06184415, ..., 0.01527563, 0.04985374,
#         0.0029515 ],
#        ...,
#        [0.01493556, 0.05601624, 0.06327368, ..., 0.01537875, 0.0547051 ,
#         0.00308981],
#        [0.01463782, 0.05728499, 0.06309294, ..., 0.01311305, 0.05718214,
#         0.00281111],
#        [0.01377299, 0.05906555, 0.0670804 , ..., 0.01415783, 0.05073643,
#         0.00274971]])

# %%
# Using reconstruction error, calculate if time sequence sample is anomalous: L(X, X') > epsilon, where epsilon is threshold

def evaluate(error, threshold=max_threshold):
    anomalies = error > threshold
    if np.sum(anomalies) >=1:
        return 1
    return 0

result = []
for i in range(len(f_error)):
    result.append(evaluate(f_error[i,]))
anomalies = np.sum(np.array(result))
anomalies
# Out:
# 0

# %%
# Plot normal data and its reconstruction

plt.figure(figsize=(12, 6))
process = 1
sample = 4
a = pd.DataFrame({'values': n_train[sample][:, process]})
b = pd.DataFrame({'values': X_rec[sample][:, process]})
mean_error = np.mean(np.abs(X_rec[sample][:, process] - n_train[sample][:, process]))
plt.title(f"Normal Data Mean Absolute Error: {mean_error}")
plt.plot(a)
plt.plot(b)
plt.legend(['Actual', 'Predicted'])
plt.show()

# %%
# Plot faulty data and its reconstruction

plt.figure(figsize=(12, 6))
process = 1
sample = 4
a = pd.DataFrame({'values': f_train[sample][:, process]})
b = pd.DataFrame({'values': y_rec[sample][:, process]})
mean_error = np.mean(np.abs(y_rec[sample][:, process] - f_train[sample][:, process]))
plt.title(f"Faulty Data Mean Absolute Error: {mean_error}")
plt.plot(a)
plt.plot(b)
plt.legend(['Actual', 'Predicted'])
plt.show()

# %% [markdown]
# ## Machine Learning Methods

# %%
# Isolation Forests

# %% [markdown]
# ## Deep Learning Methods (Autoencoders)

# %%
# 1DCNN

model = keras.Sequential(
    [
        layers.Input(shape=(n_test.shape[1], n_test.shape[2])),
        layers.Conv1D(filters=256, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.Conv1D(filters=32, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.Conv1DTranspose(filters=32, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.Conv1DTranspose(filters=256, kernel_size=3, padding="same", strides=2, activation="relu"),
        layers.Conv1DTranspose(filters=n_train.shape[2], kernel_size=3, padding="same"),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_43 (Conv1D)          (None, 250, 256)          40192
#
#  conv1d_44 (Conv1D)          (None, 125, 32)           24608
#
#  conv1d_transpose_57 (Conv1  (None, 250, 32)           3104
#  DTranspose)
#
#  conv1d_transpose_58 (Conv1  (None, 500, 256)          24832
#  DTranspose)
#
#  conv1d_transpose_59 (Conv1  (None, 500, 52)           39988
#  DTranspose)
#
# =================================================================
# Total params: 132724 (518.45 KB)
# Trainable params: 132724 (518.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(
    n_test,
    n_test,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
#     callbacks=[
#         keras.callbacks.EarlyStopping(monitor="val_loss", patience=10, mode="min")
#     ],
    verbose=2
)
# Out:
# Epoch 1/50
# 7/7 - 2s - loss: 0.0130 - val_loss: 0.0125 - 2s/epoch - 222ms/step
# Epoch 2/50
# 7/7 - 2s - loss: 0.0127 - val_loss: 0.0123 - 2s/epoch - 228ms/step
# Epoch 3/50
# 7/7 - 2s - loss: 0.0125 - val_loss: 0.0121 - 2s/epoch - 228ms/step
# Epoch 4/50
# 7/7 - 2s - loss: 0.0124 - val_loss: 0.0121 - 2s/epoch - 222ms/step
# Epoch 5/50
# 7/7 - 2s - loss: 0.0123 - val_loss: 0.0120 - 2s/epoch - 225ms/step
# Epoch 6/50
# 7/7 - 2s - loss: 0.0122 - val_loss: 0.0119 - 2s/epoch - 235ms/step
# Epoch 7/50
# 7/7 - 2s - loss: 0.0121 - val_loss: 0.0118 - 2s/epoch - 223ms/step
# Epoch 8/50
# 7/7 - 2s - loss: 0.0120 - val_loss: 0.0117 - 2s/epoch - 225ms/step
# Epoch 9/50
# 7/7 - 2s - loss: 0.0119 - val_loss: 0.0115 - 2s/epoch - 239ms/step
# Epoch 10/50
# 7/7 - 2s - loss: 0.0116 - val_loss: 0.0112 - 2s/epoch - 222ms/step
# Epoch 11/50
# 7/7 - 2s - loss: 0.0113 - val_loss: 0.0109 - 2s/epoch - 227ms/step
# Epoch 12/50
# 7/7 - 2s - loss: 0.0109 - val_loss: 0.0106 - 2s/epoch - 239ms/step
# Epoch 13/50
# 7/7 - 2s - loss: 0.0106 - val_loss: 0.0103 - 2s/epoch - 237ms/step
# Epoch 14/50
# 7/7 - 2s - loss: 0.0103 - val_loss: 0.0101 - 2s/epoch - 245ms/step
# Epoch 15/50
# 7/7 - 2s - loss: 0.0101 - val_loss: 0.0099 - 2s/epoch - 238ms/step
# Epoch 16/50
# 7/7 - 2s - loss: 0.0100 - val_loss: 0.0098 - 2s/epoch - 232ms/step
# Epoch 17/50
# 7/7 - 2s - loss: 0.0098 - val_loss: 0.0096 - 2s/epoch - 233ms/step
# Epoch 18/50
# 7/7 - 2s - loss: 0.0096 - val_loss: 0.0094 - 2s/epoch - 226ms/step
# Epoch 19/50
# 7/7 - 2s - loss: 0.0095 - val_loss: 0.0093 - 2s/epoch - 253ms/step
# Epoch 20/50
# 7/7 - 2s - loss: 0.0093 - val_loss: 0.0091 - 2s/epoch - 245ms/step
# Epoch 21/50
# 7/7 - 2s - loss: 0.0091 - val_loss: 0.0090 - 2s/epoch - 238ms/step
# Epoch 22/50
# 7/7 - 2s - loss: 0.0090 - val_loss: 0.0088 - 2s/epoch - 232ms/step
# Epoch 23/50
# 7/7 - 2s - loss: 0.0088 - val_loss: 0.0087 - 2s/epoch - 225ms/step
# Epoch 24/50
# 7/7 - 2s - loss: 0.0086 - val_loss: 0.0085 - 2s/epoch - 244ms/step
# Epoch 25/50
# 7/7 - 2s - loss: 0.0084 - val_loss: 0.0083 - 2s/epoch - 247ms/step
# Epoch 26/50
# 7/7 - 2s - loss: 0.0083 - val_loss: 0.0082 - 2s/epoch - 252ms/step
# Epoch 27/50
# 7/7 - 2s - loss: 0.0081 - val_loss: 0.0080 - 2s/epoch - 249ms/step
# Epoch 28/50
# 7/7 - 2s - loss: 0.0080 - val_loss: 0.0079 - 2s/epoch - 244ms/step
# Epoch 29/50
# 7/7 - 2s - loss: 0.0079 - val_loss: 0.0078 - 2s/epoch - 249ms/step
# Epoch 30/50
# 7/7 - 2s - loss: 0.0078 - val_loss: 0.0077 - 2s/epoch - 237ms/step
# Epoch 31/50
# 7/7 - 2s - loss: 0.0077 - val_loss: 0.0076 - 2s/epoch - 232ms/step
# Epoch 32/50
# 7/7 - 2s - loss: 0.0076 - val_loss: 0.0076 - 2s/epoch - 231ms/step
# Epoch 33/50
# 7/7 - 2s - loss: 0.0075 - val_loss: 0.0075 - 2s/epoch - 256ms/step
# Epoch 34/50
# 7/7 - 2s - loss: 0.0075 - val_loss: 0.0074 - 2s/epoch - 240ms/step
# Epoch 35/50
# 7/7 - 2s - loss: 0.0074 - val_loss: 0.0073 - 2s/epoch - 252ms/step
# Epoch 36/50
# 7/7 - 2s - loss: 0.0073 - val_loss: 0.0073 - 2s/epoch - 235ms/step
# Epoch 37/50
# 7/7 - 2s - loss: 0.0073 - val_loss: 0.0072 - 2s/epoch - 228ms/step
# Epoch 38/50
# 7/7 - 2s - loss: 0.0072 - val_loss: 0.0072 - 2s/epoch - 238ms/step
# Epoch 39/50
# 7/7 - 2s - loss: 0.0072 - val_loss: 0.0071 - 2s/epoch - 230ms/step
# Epoch 40/50
# 7/7 - 2s - loss: 0.0071 - val_loss: 0.0071 - 2s/epoch - 236ms/step
# Epoch 41/50
# 7/7 - 2s - loss: 0.0071 - val_loss: 0.0070 - 2s/epoch - 238ms/step
# Epoch 42/50
# 7/7 - 2s - loss: 0.0070 - val_loss: 0.0070 - 2s/epoch - 239ms/step
# Epoch 43/50
# 7/7 - 2s - loss: 0.0070 - val_loss: 0.0069 - 2s/epoch - 234ms/step
# Epoch 44/50
# 7/7 - 2s - loss: 0.0069 - val_loss: 0.0069 - 2s/epoch - 232ms/step
# Epoch 45/50
# 7/7 - 2s - loss: 0.0069 - val_loss: 0.0068 - 2s/epoch - 231ms/step
# Epoch 46/50
# 7/7 - 2s - loss: 0.0068 - val_loss: 0.0068 - 2s/epoch - 233ms/step
# Epoch 47/50
# 7/7 - 2s - loss: 0.0068 - val_loss: 0.0068 - 2s/epoch - 230ms/step
# Epoch 48/50
# 7/7 - 2s - loss: 0.0067 - val_loss: 0.0067 - 2s/epoch - 226ms/step
# Epoch 49/50
# 7/7 - 2s - loss: 0.0067 - val_loss: 0.0067 - 2s/epoch - 226ms/step
# Epoch 50/50
# 7/7 - 2s - loss: 0.0067 - val_loss: 0.0066 - 2s/epoch - 227ms/step

# %%
n_pred = model.predict(n_test)
error = np.mean(np.abs(n_pred - n_test), axis=1)

threshold = np.max(error, axis=0)
max_threshold = np.max(threshold)
max_threshold
# Out:
# 16/16 [==============================] - 1s 43ms/step
# 0.10749340456687757

# %%
# Faulty set

f_pred = model.predict(f_test)
error_test = np.mean(np.abs(f_pred - f_test), axis=1)
error_test
# Out:
# 313/313 [==============================] - 16s 50ms/step
# array([[0.1536212 , 0.09678051, 0.10200988, ..., 0.04568844, 0.13465736,
#         0.31593964],
#        [0.02286896, 0.16588458, 0.13178137, ..., 0.1356338 , 0.05472267,
#         0.16489397],
#        [0.03855775, 0.10610411, 0.07206606, ..., 0.01913858, 0.08577677,
#         0.18440989],
#        ...,
#        [0.10872215, 0.19241473, 0.14417594, ..., 0.22415242, 0.22899286,
#         0.15816635],
#        [0.03783942, 0.1028304 , 0.07306189, ..., 0.01704539, 0.0858978 ,
#         0.18571475],
#        [0.04068648, 0.10612367, 0.07620322, ..., 0.01679233, 0.08144752,
#         0.18045744]])

# %%
plt.figure(figsize=(12, 6))
process = 6
sample = 4
a = pd.DataFrame({'values': n_test[sample][:, process]})
b = pd.DataFrame({'values': n_pred[sample][:, process]})
mean_error = np.mean(np.abs(n_pred[sample][:, process] - n_test[sample][:, process]))
plt.title(f"Normal Data Mean Absolute Error: {mean_error}")
plt.plot(a)
plt.plot(b)
plt.legend(['Actual', 'Predicted'])
plt.show()

# %%
plt.figure(figsize=(12, 6))
process = 1
sample = 4
a = pd.DataFrame({'values': f_test[sample][:, process]})
b = pd.DataFrame({'values': f_pred[sample][:, process]})
mean_error = np.mean(np.abs(f_pred[sample][:, process] - f_test[sample][:, process]))
plt.title(f"Faulty Data Mean Absolute Error: {mean_error}")
plt.plot(a)
plt.plot(b)
plt.legend(['Actual', 'Predicted'])
plt.show()

# %%
def evaluate(error, threshold=max_threshold):
    anomalies = error > threshold
    if np.sum(anomalies) >=1:
        return 1
    return 0

result = []
for i in range(len(error_test)):
    result.append(evaluate(error_test[i,]))
anomalies = np.sum(np.array(result))
anomalies
# Out:
# 10000

# %%
# Normal Autoencoder

model = keras.Sequential(
    [
        layers.Dense(256, input_shape=(n_train.shape[1], n_train.shape[2]), activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(32, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(256, activation='relu'),
        layers.Dense(n_train.shape[2])
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 500, 256)          13568
#
#  dense_7 (Dense)             (None, 500, 64)           16448
#
#  dense_8 (Dense)             (None, 500, 32)           2080
#
#  dense_9 (Dense)             (None, 500, 64)           2112
#
#  dense_10 (Dense)            (None, 500, 256)          16640
#
#  dense_11 (Dense)            (None, 500, 52)           13364
#
# =================================================================
# Total params: 64212 (250.83 KB)
# Trainable params: 64212 (250.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
